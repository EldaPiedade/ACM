# %% [markdown]
# # SET UP:
#   * Create an account at https://www.kaggle.com/
#     * Use https://pandas.pydata.org/pandas-docs/stable/reference/frame.html for data frames.
#     * Use https://pandas.pydata.org/pandas-docs/stable/reference/series.html for series.

# %% [markdown]
# # Explore Your Data :

# %%
# Import main modules
import numpy as np
import pandas as pd
from IPython.display import Image

# %%
data = pd.read_csv('/Users/elda/Documents/ACM Workshop/data/train.csv')

# %% [markdown]
# * Take a quick look at the first rows of data.
# * Change the index( row identification) to columns ID of the data frame.

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data = pd.read_csv('/Users/elda/Documents/ACM Workshop/data/train.csv', index_col = "Id")

# %%
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# * Now, access the type of values you are given, missing values, and read the data description file to get familiar with the data.
# * The count row given by the ".describe()" method reveals the number of missing values, however, you are not able to eyeball all columns. There is an easier way for you to see all missing values.

# %%
print(data.shape) # we have 1460 rows and 80 columns.
data.describe()
# Out:
# (1460, 80)
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# ...

# %% [markdown]
# * This command returns a data series. Now you can use a boolean value mask to extract only columns with missing data.

# %%
data.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
series_data = data.isnull().sum()
series_data[series_data != 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# * Make sure you understand why certain values are marked as missing. It might be that the house was missing, for example, a fence.
# * Let us start by only working with numerical data, and build the model as we move forward.
# * How do we see which columns are numeric and which are not?

# %%
data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
new_data = data.select_dtypes(['int64','float64'])
new_data.isnull().sum() # Now we have an ease structure of data to work on.
# Out:
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %% [markdown]
# * You must have questions now about what to do with the missing values, however right now we will not focus on that.
# * Other questions you might have, how do we select which columns to keep? There are several answers:
#     * domain knowledge, or research.
#     * feature selection procedures such as PCA, Univariate Selection, Feature Importance, Correlation Matrix with Heatmap
#     ( check the link for more explanation: https://towardsdatascience.com/feature-selection-techniques-in-machine-learning-with-python-f24e7da3f36e). We will address this at the next workshop. Now let us make an easy model with no missing or categorical data.
# * Let's go ahead and drop both columns with missing values and prepare the data for our first model.

# %%
new_data = new_data.drop(['LotFrontage','GarageYrBlt', 'MasVnrArea'], axis =1)

# %% [markdown]
# # Create your model :

# %% [markdown]
# * We will start with a basic model that is very easy to understand and wildly used in the industry. The decision tree.
# * Think of it as organizing by characteristics. Does the house have more or less than 2 rooms? Does the house have a pool? Keep asking questions and you have yourself a good example of how a decision tree works.

# %%
Image("/Users/elda/Documents/ACM Workshop/img/1.png", width = 400)

# %% [markdown]
# The steps to building and using a model are:
#
# * Define: What type of model will it be? A decision tree? Some other type of model? Regression or classification problem?
# * Fit: Capture patterns from provided data. This is the heart of modeling.
# * Predict: Just what it sounds like
# * Evaluate: Determine how accurate the model's predictions are using a metric.
#
# Let us create a default model:

# %%
# Separate target from predictors
y = new_data.SalePrice
X = new_data.drop('SalePrice', axis = 1)
#X[5:10],X.head(40)

# %% [markdown]
# Split you data into a train set and a validation set,so that you can assess how your model is performing.
#
# Check link for more information :
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=1)

# %% [markdown]
# Questions you might have: why  and when do we need a validation dataset?
#
# Know that a model is built on available data so that you can make predictions on data that the model has never seen. Therefore, if you want to estimate how the model will behave with unseen data you must provide it with data that you did not use to train your model.
#
# When you train a model each time you will get different parameters of estimation. A model that has extreme variance is not a good model. If you do not have enough data available to you it is a good practice to crossvalidate your model to understand how it behaves for each given training data. We will revisit this concept on the next workshop. Now focus on a single validation data set.
#
# Read about model bias and variance : https://towardsdatascience.com/understanding-the-bias-variance-tradeoff-165e6942b229

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model. Specify a number for random_state to ensure same results each run
model = DecisionTreeRegressor(random_state=1)

# Fit model
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')

# %% [markdown]
# # Model Validation:

# %% [markdown]
# * Now that you trained your model you need a measure or metric to compare it to your future models.
# * We will use mean_absolute_error
# * Common metrics used for regression problems are :
#     * Mean Absolute Error
#     * Mean Square Error
#     * Mean Absolute Percentage Error
#     * Mean Percentage Error
#     * ( read more: https://www.dataquest.io/blog/understanding-regression-error-metrics/)

# %%
Image("/Users/elda/Documents/ACM Workshop/img/2.png", width = 400)

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = model.predict(X_valid)
mean_absolute_error(y_valid, predicted_home_prices)
# Out:
# 23017.719178082192

# %% [markdown]
# # Your Task 1:
#
# * Read more about decision trees https://scikit-learn.org/stable/modules/tree.html.
# * Change model parameters to get a better result ( smaller mean absolute_error). (more parameters:https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor)
#     * Example : Tree's depth, that is how many splits it makes before coming to a prediction.
# * Compare all your different results and note the difference.

# %% [markdown]
# ### Underfitting and Overfitting
#
# In practice, it's not uncommon for a tree to have 10 splits between the top level (all houses) and a leaf. As the tree gets deeper, the dataset gets sliced up into leaves with fewer houses. If a tree only had 1 split, it divides the data into 2 groups. If each group is split again, we would get 4 groups of houses. Splitting each of those again would create 8 groups. If we keep doubling the number of groups by adding more splits at each level, we'll have  210  groups of houses by the time we get to the 10th level. That's 1024 leaves.
#
# When we divide the houses amongst many leaves, we also have fewer houses in each leaf. Leaves with very few houses will make predictions that are quite close to those homes' actual values, but they may make very unreliable predictions for new data (because each prediction is based on only a few houses).
#
# This is a phenomenon called overfitting, where a model matches the training data almost perfectly, but does poorly in validation and other new data. On the flip side, if we make our tree very shallow, it doesn't divide up the houses into very distinct groups
#
# ##### Underfitting
# When a model fails to capture important distinctions and patterns in the data, so it performs poorly even in training data, that is called underfitting.
#
# #### Overfitting
# Where a model matches the training data almost perfectly, but does poorly in validation and other new data.

# %% [markdown]
# # Your Task 2:
#     * Compare MAE with different values of max_leaf_nodes. ( Use the function below and customize it if you want).
#     * describe what you have notice.

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %% [markdown]
# # Random Forests

# %% [markdown]
# * Random forest is an ensemble method. It combines differents trees and averages the different results to make a prediction.
# * Random Forest works well with default parameters.
# * Ensemble methods tend to work better than singular methods. ( read more : https://blog.statsbot.co/ensemble-learning-d1dcd548e936)

# %% [markdown]
# # Your Task 3:
# Experiment using a Random Forest and read more about it :
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(X_train,y_train)
preds = forest_model.predict(X_train)
print(mean_absolute_error(y_train, preds))
# Out:
# 6788.7715211187215

# %% [markdown]
# # Use final model to predict using new data ?

# %% [markdown]
# * You must train the model with all available data. No more splitting to validate it.
# * You must apply the same treatments to the new data as you did to the training data.
# * In our case we will use only the columns we selected to predict the sale price.

# %%
final_model = RandomForestRegressor(random_state=1)
final_model.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)

# %%
# upload you new data:
test_data = pd.read_csv('/Users/elda/Documents/ACM Workshop/data/test.csv', index_col ='Id')

# prepare your new data:

test_data = test_data[X.columns]

# %%
test_data.isnull().sum() # we have a few missing values (We will discuss this on next workshop)
# Out:
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       1
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     2
# BsmtHalfBath     2
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       1
# GarageArea       1
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
test_data.head()
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1461          20    11622            5            6       1961          1961
# 1462          20    14267            6            6       1958          1958
# 1463          60    13830            5            5       1997          1998
# 1464          60     9978            6            6       1998          1998
# 1465         120     5005            8            5       1992          1992
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageArea  \
# Id                                                    ...
# 1461       468.0       144.0      270.0        882.0  ...       730.0
# 1462       923.0         0.0      406.0       1329.0  ...       312.0
# 1463       791.0         0.0      137.0        928.0  ...       482.0
# 1464       602.0         0.0      324.0        926.0  ...       470.0
# 1465       263.0         0.0     1017.0       1280.0  ...       506.0
#
# ...

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer()
imputed_X_train= pd.DataFrame(my_imputer.fit_transform(X))
imputed_X_test= pd.DataFrame(my_imputer.transform(test_data))

# Imputation removed column names; put them back
imputed_X_train.columns = X.columns
imputed_X_test.columns = test_data.columns
imputed_X_test.index = test_data.index

# %%
imputed_X_test.head()
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1461        20.0  11622.0          5.0          6.0     1961.0        1961.0
# 1462        20.0  14267.0          6.0          6.0     1958.0        1958.0
# 1463        60.0  13830.0          5.0          5.0     1997.0        1998.0
# 1464        60.0   9978.0          6.0          6.0     1998.0        1998.0
# 1465       120.0   5005.0          8.0          5.0     1992.0        1992.0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageArea  \
# Id                                                    ...
# 1461       468.0       144.0      270.0        882.0  ...       730.0
# 1462       923.0         0.0      406.0       1329.0  ...       312.0
# 1463       791.0         0.0      137.0        928.0  ...       482.0
# 1464       602.0         0.0      324.0        926.0  ...       470.0
# 1465       263.0         0.0     1017.0       1280.0  ...       506.0
#
# ...

# %%
preds = forest_model.predict(imputed_X_test)

# %%
# Save predictions in format used for competition scoring
output = pd.DataFrame({'Id': imputed_X_test.index,
                       'SalePrice': preds })

# %%
output
# Out:
#         Id  SalePrice
# 0     1461  128680.26
# 1     1462  152913.50
# 2     1463  179467.14
# 3     1464  182721.00
# 4     1465  195741.13
# ...    ...        ...
# 1454  2915   86392.00
# 1455  2916   86892.50
# 1456  2917  155050.01
# 1457  2918  122795.36
# 1458  2919  237437.14
#
# [1459 rows x 2 columns]

# %%
output.to_csv('submission_Feb_19.csv', index=False)

# %% [markdown]
# # Your Task 4:
# * Improve your model using the tools you learned today.
# * What happens if you reduce the numbers of columns? Does your model become better or worst?
# * Change Random forest parameters like n_estimators(the number of trees on your forest.

# %% [markdown]
# # NEXT WORKSHOP:
# * Missing values.
# * categorical data.
# * Cross-Validation.
# * possibly (pipelines)
# * XGBoot.
